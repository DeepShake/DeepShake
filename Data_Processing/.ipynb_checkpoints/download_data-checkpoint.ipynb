# %%
import obspy
import matplotlib.pyplot as plt
import os
import datetime
import logging
import time

# %%
logger = logging.getLogger('Seismic data downloading')
logger.setLevel(logging.DEBUG)
fh = logging.FileHandler('downloading.log')
# fh.setLevel(logging.DEBUG)
logger.addHandler(fh)
ch = logging.StreamHandler()
# ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %%
center = (35.705, -117.504)
horizontal = 0.5
vertical = 0.5
coords = [
    [35.705 - 0.5, -117.504 - 0.5],
    [35.705 + 0.5, -117.504 - 0.5],
    [35.705 - 0.5, -117.504 + 0.5],
    [35.705 + 0.5, -117.504 + 0.5]
]
print(coords)
# Out:
# [[35.205, -118.004], [36.205, -118.004], [35.205, -117.004], [36.205, -117.004]]

# %%
starttime = obspy.UTCDateTime("2019-07-05")
endtime = obspy.UTCDateTime("2019-07-06")
# starttime = obspy.UTCDateTime("2019-04-01")
# endtime = obspy.UTCDateTime("2019-07-01")

# %%
from obspy.clients.fdsn import Client
client = Client("SCEDC")

# %%
output_dir = "./mseed2"
if not os.path.exists(output_dir):
  os.makedirs(output_dir)

# %%
events = client.get_events(starttime=starttime, 
                           endtime=endtime, 
                           minlatitude=center[0]-vertical,
                           maxlatitude=center[0]+vertical,
                           minlongitude=center[1]-horizontal,
                           maxlongitude=center[1]+horizontal,
                           minmagnitude=3, 
                           catalog="SCEDC", 
                           filename='events.xml')
# events = obspy.read_events('events.xml')
# events.plot('local', outfile="events.png")
# plt.savefig("events.png")
# logger.info("Number of events: {}".format(len(events)))

# %%
events = obspy.read_events('events.xml')
# logger.info("Number of events: {}".format(len(events)))
print(events)
# Out:
# 38 Event(s) in Catalog:
# 2019-07-05T10:16:34.490000Z | +35.664, -117.503 | 3.1 Ml | manual
# 2019-07-05T11:07:53.040000Z | +35.760, -117.575 | 5.36 Mw | manual
# ...
# 2019-07-05T02:01:41.150000Z | +35.774, -117.617 | 3.25 Ml | manual
# 2019-07-05T03:15:18.700000Z | +35.630, -117.566 | 3.24 Ml | manual
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
plt.figure(figsize=(15,15))
fig = plt.subplot()
# events.plot('local', outfile="events.png", fig=fig)
#fig = events.plot('local', fig=fig)
# plt.savefig("events.png")

# %%
stations = client.get_stations(network = "*",
                               station = "*",
                               starttime=obspy.UTCDateTime("2019-04-01"), 
                               endtime=obspy.UTCDateTime("2019-09-01"), 
                               minlatitude=center[0]-vertical,
                               maxlatitude=center[0]+vertical,
                               minlongitude=center[1]-horizontal,
                               maxlongitude=center[1]+horizontal,
                               level="response",
                               filename='stations.xml')
stations = obspy.read_inventory('stations.xml')
stations.plot('local', outfile="station.png")
# plt.savefig("station.png")
# Out:
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/obspy/imaging/maps.py:45: UserWarning: basemap/pyproj with proj4 version >= 5 has a bug that results in inverted map axes. Your maps may be wrong. Please use another version of proj4, or use cartopy.
#   warnings.warn(msg)
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/obspy/imaging/maps.py:387: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   width=width, height=height, ax=ax)
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/obspy/imaging/maps.py:435: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   bmap.drawcountries(color="0.75")

# %%
stations = obspy.read_inventory('stations.xml')

# %%
stations_locs = {}
for network in stations:
    for station in network:
        print(f"{network.code}.{station.code} {station.latitude} {station.longitude}")
# Out:
# CI.CCC 35.52495 -117.36453
# CI.CLC 35.81574 -117.59751
# CI.DTP 35.26742 -117.84581
# CI.JRC2 35.98249 -117.80885
# CI.LRL 35.47954 -117.68212
# CI.MPM 36.05799 -117.48901
# CI.Q0072 35.609617 -117.666721
# CI.SLA 35.89095 -117.28332
# CI.SRT 35.69235 -117.75051
# CI.TOW2 35.80856 -117.76488
# CI.WBM 35.60839 -117.89049
# CI.WCS2 36.02521 -117.76526
# CI.WMF 36.11758 -117.85486
# CI.WNM 35.8422 -117.90616
# CI.WRC2 35.9479 -117.65038
# CI.WRV2 36.00774 -117.8904
# CI.WVP2 35.94939 -117.81769
# GS.CA01 35.66512 -117.42368
# GS.CA02 35.82915 -117.35542
# GS.CA03 35.62204 -117.569107
# GS.CA04 35.478329 -117.560204
# GS.CA05 35.58926 -117.286888
# GS.CA06 35.599621 -117.492683
# GS.CA07 35.790588 -117.358032
# GS.CA08 35.769199 -117.375603
# GS.CA09 35.621552 -117.672348
# GS.CA10 35.56736 -117.667427
# NP.1809 36.10954 -117.95651
# NP.5419 35.64906 -117.66187
# PB.B916 36.1925 -117.6685
# PB.B917 35.4053 -117.2588
# PB.B918 35.9357 -117.6017
# PB.B921 35.5865 -117.4622
# ZY.SV01 35.6455 -117.4776
# ZY.SV02 35.8855 -117.7048
# ZY.SV03 35.7705 -117.5997
# ZY.SV04 35.9023 -117.7018
# ZY.SV05 35.7224 -117.5719
# ZY.SV06 35.6012 -117.3811
# ZY.SV07 35.6976 -117.6032
# ZY.SV08 35.5761 -117.4187

# %%
print(f"Number of stations: {len(stations)}")
# Out:
# Number of stations: 5

# %%
plt.figure(figsize=(15,15))
# fig = plt.gcf()
#stations.plot('local', outfile="station-event.png", size=100, fig=fig)
# plt.savefig("station.png")

# %%
def download_all_stations(stations, starttime, endtime):
  max_retry = 5
  stream = obspy.Stream()
  logger.info("#########{}#########".format(starttime))
  for network in stations:
    for station in network:
      logger.info("********{}.{}********".format(network.code, station.code))
      if network.code == "CI" and station.code == "CCC":
            continue
      retry = 0
      while retry < 8:
        try:
          tmp = client.get_waveforms(network.code, station.code, "*", "HN*", starttime, endtime)
          stream += tmp
          break
        except Exception as e:
#           logger.warning("Error {}.{}: {}".format(network.code, station.code,e))
          err = e
          retry += 1
          time.sleep(1)
          continue
      if retry >= max_retry:
        logger.warning("MAX retries reach at {}.{} with error: {}".format(network.code, station.code, err))

  return stream

# %%
tmp_start = starttime
one_day = datetime.timedelta(days=1)
while tmp_start < endtime:
  stream = download_all_stations(stations, tmp_start, tmp_start+one_day)
  stream.write(os.path.join(output_dir, "{}.mseed".format(tmp_start.datetime.strftime("%Y-%m-%d"))), format="MSEED")  
  tmp_start += one_day
# Out:
# #########2019-07-05T00:00:00.000000Z#########
# ********CI.CCC********
# ********CI.CLC********
# ********CI.DTP********
# ********CI.JRC2********
# ********CI.LRL********
# ********CI.MPM********
# ********CI.Q0072********
# MAX retries reach at CI.Q0072 with error: No data available for request.
# Detailed response of server:
#
#
# ********CI.SLA********
# ********CI.SRT********
# ********CI.TOW2********
# ********CI.WBM********
# ********CI.WCS2********
# ********CI.WMF********
# ********CI.WNM********
# ********CI.WRC2********
# ********CI.WRV2********
# ********CI.WVP2********
# ********GS.CA01********
# MAX retries reach at GS.CA01 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA02********
# MAX retries reach at GS.CA02 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA03********
# MAX retries reach at GS.CA03 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA04********
# MAX retries reach at GS.CA04 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA05********
# MAX retries reach at GS.CA05 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA06********
# MAX retries reach at GS.CA06 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA07********
# MAX retries reach at GS.CA07 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA08********
# MAX retries reach at GS.CA08 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA09********
# MAX retries reach at GS.CA09 with error: No data available for request.
# Detailed response of server:
#
#
# ********GS.CA10********
# MAX retries reach at GS.CA10 with error: No data available for request.
# Detailed response of server:
#
#
# ********NP.1809********
# MAX retries reach at NP.1809 with error: No data available for request.
# Detailed response of server:
#
#
# ********NP.5419********
# MAX retries reach at NP.5419 with error: No data available for request.
# Detailed response of server:
#
#
# ********PB.B916********
# MAX retries reach at PB.B916 with error: No data available for request.
# Detailed response of server:
#
#
# ********PB.B917********
# MAX retries reach at PB.B917 with error: No data available for request.
# Detailed response of server:
#
#
# ********PB.B918********
# MAX retries reach at PB.B918 with error: No data available for request.
# Detailed response of server:
#
#
# ********PB.B921********
# MAX retries reach at PB.B921 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV01********
# MAX retries reach at ZY.SV01 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV02********
# MAX retries reach at ZY.SV02 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV03********
# MAX retries reach at ZY.SV03 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV04********
# MAX retries reach at ZY.SV04 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV05********
# MAX retries reach at ZY.SV05 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV06********
# MAX retries reach at ZY.SV06 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV07********
# MAX retries reach at ZY.SV07 with error: No data available for request.
# Detailed response of server:
#
#
# ********ZY.SV08********
# MAX retries reach at ZY.SV08 with error: No data available for request.
# Detailed response of server:
