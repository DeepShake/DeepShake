# %% [markdown]
# # DeepShake Multi-step Time Series Forecasting

# %% [markdown]
# This notebook is a template for doing time series forecasting on the Ridgecrest dataset

# %%
import sys
sys.path.append("./networks/.")
sys.path.append("../utils/.")

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
#tf.enable_eager_execution()

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

tf.random.set_random_seed(13)

import py3nvml
py3nvml.grab_gpus(1)

from utils import *
from lstm import *
# Out:
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## The Ridgecrest Dataset and parsed data
# This notebook uses a earthquake dataset from Ridgecrest, collected from July to September of 2019.
# There are several thousand earthquakes during this time period, which were collected at anywhere from 16-30 stations.

# %%
dataset = np.load('../data/acc/compressed/full_data.npy')
print("Before: ", dataset.shape)
#Swap axes
dataset = dataset.swapaxes(1, -1)

#Combine station and xyz
#dataset = dataset.reshape(dataset.shape[0], dataset.shape[1], -1)
print("After: ", dataset.shape)
# Out:
# Before:  (35679, 15, 60)
# After:  (35679, 60, 15)

# %%
data_path = "../data/minute_norm_acc"

x_train_multi = np.load(os.path.join(data_path, "X_train.npy"))
y_train_multi = np.load(os.path.join(data_path, "y_train.npy"))
x_val_multi = np.load(os.path.join(data_path, "X_val.npy"))
y_val_multi = np.load(os.path.join(data_path, "y_val.npy"))

y_train_multi = y_train_multi.reshape((y_train_multi.shape[0], -1))
y_val_multi = y_val_multi.reshape((y_val_multi.shape[0], -1))

richters_discrete = np.load(os.path.join(data_path, "richters_discrete.npy"))

# %%
plt.hist(np.abs(x_train_multi).sum(axis=-1).sum(axis=-1), bins=50)
plt.show()

# %%
print(x_train_multi.shape)
print(y_train_multi.shape)

# idxs = np.abs(x_train_multi).sum(axis=-1).sum(axis=-1) >= 18
# x_train_multi = x_train_multi[idxs]
# y_train_multi = y_train_multi[idxs]

print(x_train_multi.shape)
print(y_train_multi.shape)
# Out:
# (1754375, 15, 15)
# (1754375, 150)
# (1754375, 15, 15)
# (1754375, 150)

# %%
import json
config_path = os.path.join(data_path, "config.json")
with open(config_path) as json_file:
    config = json.load(json_file)
    
_, past_history, STEP, future_target, train_distrib, val_distrib = list(config.values())

TRAIN_SPLIT_IDX = sum(train_distrib)

# %% [markdown]
# ### Multi-Step model
# In a multi-step prediction model, given a past history, the model needs to learn to predict a range of future values. Thus, unlike a single step model, where only a single future point is predicted, a multi-step model predict a sequence of the future.
#
# For the multi-step model, the training data again consists of recordings over the past five days sampled every hour. However, here, the model needs to learn to predict the temperature for the next 12 hours. Since an obversation is taken every 10 minutes, the output is 72 predictions. For this task, the dataset needs to be prepared accordingly, thus the first step is just to create it again, but with a different target window.

# %%
# ## Original Definition

multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(128,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(64, return_sequences=True, activation='relu'))
multi_step_model.add(tf.keras.layers.LSTM(64, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(y_train_multi.shape[-1]))

multi_step_model.compile(optimizer='nadam', loss='mae', metrics= ['mse', 'mae'])
multi_step_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 15, 128)           73728
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 15, 64)            49408
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 150)               9750
# =================================================================
# Total params: 165,910
# Trainable params: 165,910
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ## Time-distributed predictions

# multi_step_model = tf.keras.models.Sequential()
# multi_step_model.add(tf.keras.layers.LSTM(128,
#                                           return_sequences=True,
#                                           input_shape=x_train_multi.shape[-2:]))
# multi_step_model.add(tf.keras.layers.LSTM(64, return_sequences=True, activation='relu'))
# multi_step_model.add(tf.keras.layers.LSTM(64, return_sequences=True, activation='relu'))
# multi_step_model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(y_train_multi.shape[-1]))) #Time-distributes 15 neurons
# # multi_step_model.add(tf.keras.layers.Dense(y_train_multi.shape[-1]))

# multi_step_model.compile(optimizer='nadam', loss='mae', metrics= ['mse', 'mae'])
# multi_step_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 15, 128)           73728
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 15, 64)            49408
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 15, 64)            33024
# _________________________________________________________________
# time_distributed (TimeDistri (None, 15, 15)            975
# =================================================================
# Total params: 157,135
# Trainable params: 157,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ## Original Definition

# multi_step_model = tf.keras.models.Sequential()
# # multistep_model.add(Lambda(lambda x: K.l2_normalize(x,axis=1)))
# multi_step_model.add(tf.keras.layers.LSTM(128,
#                                           return_sequences=True,
#                                           input_shape=x_train_multi.shape[-2:]))
# multi_step_model.add(tf.keras.layers.LSTM(64, return_sequences=True, activation='relu'))
# multi_step_model.add(tf.keras.layers.LSTM(64, activation='relu'))
# multi_step_model.add(tf.keras.layers.Dense(y_train_multi.shape[-1]))

# multi_step_model.compile(optimizer='nadam', loss='mae', metrics= ['mse', 'mae'])
# multi_step_model.summary()

# %%
print("Distribution of discrete richter magnitudes (<1, 1-3, 3-5, >=5):")
print("Train set: ", train_distrib)
print("Val set: ", val_distrib)
# Out:
# Distribution of discrete richter magnitudes (<1, 1-3, 3-5, >=5):
# Train set:  [8560, 19193, 786, 4]
# Val set:  [2168, 4778, 188, 2]

# %% [markdown]
# Let's check out a sample data-point.

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target earthquake signal to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (15, 15)
#
#  Target earthquake signal to predict : (150,)

# %% [markdown]
# Plotting a sample data-point.

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 0]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future[:, 0]), 'b--',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction[:, 0]), 'r--',
             label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# In this plot and subsequent similar plots, the history and the future data are sampled every hour.

# %%
multi_step_plot(x_train_multi[0], y_train_multi[0].reshape(-1, 15), np.array([0]))

# %% [markdown]
# Since the task here is a bit more complicated than the previous task, the model now consists of two LSTM layers.

# %%
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,CSVLogger
from keras import optimizers

lr = 0.01
BATCH_SIZE=2048
save_path = "./trained_models_acc/multistep"
# cur_file = "LSTM3_10steps_dropzero"
cur_file = 'LSTM_newnorm'
cur_file = os.path.join(save_path, cur_file)

opt = optimizers.Nadam(learning_rate=lr, beta_1=0.9, beta_2=0.999)
early_stop = EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=3,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True,
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=1,
    verbose=0,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0,
)
model_check = ModelCheckpoint(cur_file + '.h5', monitor='val_loss', verbose=1, save_best_only=True, 
                              save_weights_only=True, mode='min')
csv_log = CSVLogger(cur_file+ '_history.csv')
callback_list = [early_stop, reduce_lr, model_check, csv_log]

# %% [markdown]
# Let's see how the model predicts before it trains.

# %%
print(multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE).shape)
# Out:
# (249760, 150)

# %%
EPOCHS = 20
multi_step_history = multi_step_model.fit(x_train_multi, y_train_multi, epochs=EPOCHS,
                                          validation_data=(x_val_multi, y_val_multi), 
                                          batch_size = BATCH_SIZE, callbacks=callback_list)
# Out:
# Train on 1754375 samples, validate on 249760 samples
# WARNING:tensorflow:From /opt/anaconda3/envs/quakes/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0668 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0668
# Epoch 00001: val_loss improved from inf to 0.06746, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 137s 78us/sample - loss: 0.0668 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0668 - val_loss: 0.0675 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0675
# Epoch 2/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0605 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0605
# Epoch 00002: val_loss improved from 0.06746 to 0.06539, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 76us/sample - loss: 0.0605 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0605 - val_loss: 0.0654 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0654
# Epoch 3/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0583 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0583
# Epoch 00003: val_loss improved from 0.06539 to 0.06356, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 133s 76us/sample - loss: 0.0583 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0583 - val_loss: 0.0636 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0636
# Epoch 4/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0570 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0570
# Epoch 00004: val_loss improved from 0.06356 to 0.06291, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0570 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0570 - val_loss: 0.0629 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0629
# Epoch 5/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0561 - mean_squared_error: 0.0103 - mean_absolute_error: 0.0561
# Epoch 00005: val_loss improved from 0.06291 to 0.06233, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0561 - mean_squared_error: 0.0103 - mean_absolute_error: 0.0561 - val_loss: 0.0623 - val_mean_squared_error: 0.0119 - val_mean_absolute_error: 0.0623
# Epoch 6/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0554 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0554
# Epoch 00006: val_loss improved from 0.06233 to 0.06193, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0554 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0554 - val_loss: 0.0619 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0619
# Epoch 7/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0549 - mean_squared_error: 0.0100 - mean_absolute_error: 0.0549
# Epoch 00007: val_loss improved from 0.06193 to 0.06173, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 133s 76us/sample - loss: 0.0549 - mean_squared_error: 0.0100 - mean_absolute_error: 0.0549 - val_loss: 0.0617 - val_mean_squared_error: 0.0116 - val_mean_absolute_error: 0.0617
# Epoch 8/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0545 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0545
# Epoch 00008: val_loss improved from 0.06173 to 0.06159, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 133s 76us/sample - loss: 0.0545 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0545 - val_loss: 0.0616 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0616
# Epoch 9/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0541 - mean_squared_error: 0.0098 - mean_absolute_error: 0.0541
# Epoch 00009: val_loss improved from 0.06159 to 0.06130, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 76us/sample - loss: 0.0541 - mean_squared_error: 0.0098 - mean_absolute_error: 0.0541 - val_loss: 0.0613 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0613
# Epoch 10/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0538 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0538
# Epoch 00010: val_loss improved from 0.06130 to 0.06103, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 76us/sample - loss: 0.0538 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0538 - val_loss: 0.0610 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0610
# Epoch 11/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0534 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0534
# Epoch 00011: val_loss improved from 0.06103 to 0.06088, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0534 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0534 - val_loss: 0.0609 - val_mean_squared_error: 0.0115 - val_mean_absolute_error: 0.0609
# Epoch 12/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0531 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0531
# Epoch 00012: val_loss improved from 0.06088 to 0.06073, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0531 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0531 - val_loss: 0.0607 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0607
# Epoch 13/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0528 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0528
# Epoch 00013: val_loss improved from 0.06073 to 0.06053, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0528 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0528 - val_loss: 0.0605 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0605
# Epoch 14/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0526 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0526
# Epoch 00014: val_loss improved from 0.06053 to 0.06047, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0526 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0526 - val_loss: 0.0605 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0605
# Epoch 15/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0522 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0522
# Epoch 00015: val_loss improved from 0.06047 to 0.06027, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0522 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0522 - val_loss: 0.0603 - val_mean_squared_error: 0.0113 - val_mean_absolute_error: 0.0603
# Epoch 16/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0521 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0521
# Epoch 00016: val_loss did not improve from 0.06027
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0521 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0521 - val_loss: 0.0603 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0603
# Epoch 17/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0519 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0519
# Epoch 00017: val_loss improved from 0.06027 to 0.06022, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 134s 77us/sample - loss: 0.0519 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0519 - val_loss: 0.0602 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0602
# Epoch 18/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0517 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0517
# Epoch 00018: val_loss improved from 0.06022 to 0.06020, saving model to ./trained_models_acc/multistep/LSTM_newnorm.h5
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0517 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0517 - val_loss: 0.0602 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0602
# Epoch 19/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0517 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0517
# Epoch 00019: val_loss did not improve from 0.06020
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0517 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0517 - val_loss: 0.0602 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0602
# Epoch 20/20
# 1753088/1754375 [============================>.] - ETA: 0s - loss: 0.0516 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0516
# Epoch 00020: val_loss did not improve from 0.06020
# 1754375/1754375 [==============================] - 135s 77us/sample - loss: 0.0516 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0516 - val_loss: 0.0602 - val_mean_squared_error: 0.0112 - val_mean_absolute_error: 0.0602

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %% [markdown]
# ### Evaluate

# %%
# np.save(os.path.join(save_path, "X_train_original.npy"), x_train_original)
# np.save(os.path.join(save_path, "y_train_original.npy"), y_train_original)
means = np.load(os.path.join(data_path, "mean_val.npy"))
var = np.load(os.path.join(data_path, "var_val.npy"))
x_val_original = np.load(os.path.join(data_path, "X_val_original.npy"))
y_val_original = np.load(os.path.join(data_path, "y_val_original.npy"))
# print(multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE).shape)
y_val_preds = multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE)
y_val_preds = np.reshape(y_val_preds, (y_val_original.shape[0], -1, 15))
# y_val_preds = multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE).reshape(-1, int(y_val_original[1]), int(y_val_original[2]))
assert y_val_original.shape == y_val_preds.shape
y_val_original[y_val_original==0] = 1

y_val_preds = y_val_preds * var + means
print("Mean absolute error: ", np.mean(np.abs((y_val_preds / y_val_original) - np.ones_like(y_val_original))))
# Out:
# Mean absolute error:  11173073888.861435

# %% [markdown]
# #### Predict a multi-step future
# Let's now have a look at how well your network has learnt to predict the future.

# %%
x = x_val_multi[:20]
y = y_val_multi[:20].reshape(len(x), -1, 15)
pred_y = multi_step_model.predict(x).reshape(len(x), -1, 15)
for i in range(10):
    multi_step_plot(x[i], y[i], pred_y[i])

# %%
pred_y = multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE).reshape(len(x_val_multi), -1, 15)
pred_y.shape
# Out:
# (285440, 5, 15)

# %%
for i in range(5):
    plt.figure()
    data = x_val_multi[:, i, 0]
    data = data[data < 100]
    plt.hist(data)
    plt.show()

# %% [markdown]
# # Analyze the predictions of the model

# %%
y_pred = multi_step_model.predict(x_val_multi, batch_size = BATCH_SIZE).reshape(-1)
y_true = y_val_multi.reshape(-1)
y_pred.shape, y_true.shape
# Out:
# ((21408000,), (21408000,))

# %%
from sklearn import metrics

print("Explained Variance Score:", metrics.explained_variance_score(y_true, y_pred)) 
print("Max Error Score:", metrics.max_error(y_true, y_pred)) 
print("Mean Absolute Error Score:", metrics.mean_absolute_error(y_true, y_pred)) 
print("Mean Squared Error Score:", metrics.mean_squared_error(y_true, y_pred)) 
print("Median Absolute Error Score:", metrics.median_absolute_error(y_true, y_pred)) 
print("R2 Score:", metrics.r2_score(y_true, y_pred))
# Out:
# Explained Variance Score: 0.40436054873364513
# Max Error Score: 1.0508267626706946
# Mean Absolute Error Score: 0.060649021552208804
# Mean Squared Error Score: 0.011735154498687433
# Median Absolute Error Score: 0.027691833251122965
# R2 Score: 0.3872123834781652
